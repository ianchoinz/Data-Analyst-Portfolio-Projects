# %% [markdown]
# ## Mission 2: Exploring and Analyzing Data with Pandas
#
# Objective:
#
# In this mission, you will perform Exploratory Data Analysis (EDA) and basic data manipulation using Pandas. You will work with a dataset that includes information about employees and apply various data transformation techniques, including handling missing values, filtering, and performing basic data analysis.
#
# Dataset Overview:
#
# The dataset contains the following columns:
#
# employee_id: Unique identifier for each employee.
#
# name: Name of the employee.
#
# age: Age of the employee.
#
# department: The department where the employee works (e.g., HR, Engineering, Marketing).
#
# salary: Annual salary of the employee.
#
# work_experience: Number of years of work experience the employee has.

# %% [markdown]
# ## Task 1: Load the Data
# Objective: Load the dataset into a Pandas DataFrame.
#
# Instructions:
#
# Create a DataFrame from the provided dataset.
#
# Display the first few rows of the dataset to ensure it loaded correctly.

# %%
import pandas as pd

# Create a basic dataset
data = {
    'employee_id': range(1, 21),
    'name': ['John', 'Jane', 'Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Hannah', 'Ivy', 'Jack', 'Karen', 'Leo', 'Mia', 'Nina', 'Olivia', 'Paul', 'Quinn', 'Rita'],
    'age': [22, 25, 28, 35, 40, 42, 50, 60, 65, 30, 28, 24, 37, 41, 48, 33, 29, 32, 45, 38],
    'department': ['HR', 'Engineering', 'Marketing', 'Finance', 'Sales', 'HR', 'Engineering', 'Marketing', 'Finance', 'Sales', 'HR', 'Engineering', 'Marketing', 'Finance', 'Sales', 'HR', 'Engineering', 'Marketing', 'Finance', 'Sales'],
    'salary': [50000, 60000, 55000, 75000, 80000, 85000, 100000, 110000, 120000, 65000, 67000, 72000, 85000, 90000, 95000, 48000, 67000, 70000, 80000, 88000],
    'work_experience': [1, 3, 5, 7, 10, 12, 15, 18, 20, 3, 1, 6, 4, 8, 5, 7, 3, 2, 6, 5],
}
# Out:
# StatementMeta(, c3b0ff2f-23f5-4749-8c1b-28e8f6692ef3, 5, Finished, Available, Finished, False)

# %% [markdown]
# ### Task 2: Data Exploration
#
# Objective: Explore the dataset to get an understanding of its structure.
#
# Instructions:
#
# Check for missing values in the dataset.
#
# Get the summary statistics of numeric columns (age, salary, work_experience).

# %%
df = pd.DataFrame(data)
print(df.isnull().sum())
print(df[['age', 'salary', 'work_experience']])
# Out:
# StatementMeta(, c3b0ff2f-23f5-4749-8c1b-28e8f6692ef3, 6, Finished, Available, Finished, False)
# employee_id        0
# name               0
# age                0
# department         0
# salary             0
# work_experience    0
# dtype: int64
#     age  salary  work_experience
# 0    22   50000                1
# 1    25   60000                3
# 2    28   55000                5
# 3    35   75000                7
# 4    40   80000               10
# 5    42   85000               12
# 6    50  100000               15
# 7    60  110000               18
# 8    65  120000               20
# 9    30   65000                3
# 10   28   67000                1
# 11   24   72000                6
# 12   37   85000                4
# 13   41   90000                8
# 14   48   95000                5
# 15   33   48000                7
# 16   29   67000                3
# 17   32   70000                2
# 18   45   80000                6
# 19   38   88000                5

# %% [markdown]
# ### Task 3: Data Transformation
#
# Objective: Perform basic data transformations such as creating new columns and renaming existing ones.
#
# Instructions:
#
# Create a new column called years_to_retirement by subtracting the age from 65.
#
# Rename the salary column to annual_salary.
#
# Sort the DataFrame based on work_experience in descending order.

# %%
df['years_to_retirement'] = 65 - df['age']
df = df.rename(columns={'salary': 'annual_salary'})
df = df.sort_values(by='work_experience', ascending=False)
display(df)
# Out:
# StatementMeta(, c3b0ff2f-23f5-4749-8c1b-28e8f6692ef3, 10, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, cb33d1f0-60e7-45f9-86e6-5503f3cc6c8c)

# %% [markdown]
# ### Task 4: Handling Missing Data
#
# Objective: Handle missing data (if any).
#
# Instructions:
#
# Introduce some missing values in the annual_salary column.
#
# Handle the missing data by either filling it with the mean salary or dropping the rows with missing values.

# %%
display(df['annual_salary'])
print(df.isnull().sum())
mean_salary = df['annual_salary'].mean()
df_filled = df.fillna({'annual_salary': mean_salary})
print(df_filled.isnull().sum())
df_dropped = df.dropna()
print(df_dropped.isnull().sum())
# Out:
# StatementMeta(, c3b0ff2f-23f5-4749-8c1b-28e8f6692ef3, 20, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 2f65f291-5b2a-44cd-a687-c3eab483c164)
# employee_id            0
# name                   0
# age                    0
# department             0
# annual_salary          0
# work_experience        0
# years_to_retirement    0
# dtype: int64
# employee_id            0
# name                   0
# age                    0
# department             0
# annual_salary          0
# work_experience        0
# years_to_retirement    0
# dtype: int64
# employee_id            0
# name                   0
# age                    0
# department             0
# annual_salary          0
# work_experience        0
# years_to_retirement    0
# dtype: int64

# %% [markdown]
# ## Task 5: Data Filtering and Selection
# Objective: Select specific data based on conditions.
#
# Instructions:
#
# Filter the data to show only employees who are older than 30.
#
# Select only the columns name, age, and annual_salary.

# %%
df_over30 = df[df['age'] > 30]
display(df_over30)
print(df_over30.sum())

df_selected = df_over30[['name', 'age', 'annual_salary']]
display(df_selected)
print(df_selected.sum())
# Out:
# StatementMeta(, c3b0ff2f-23f5-4749-8c1b-28e8f6692ef3, 23, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 2b27d449-19b5-4c1b-ab26-3d439ca7a51e)
# employee_id                                                          154
# name                   GraceFrankEveDavidCharlieLeoNinaBobQuinnMiaRit...
# age                                                                  566
# department             FinanceMarketingEngineeringHRSalesFinanceHRFin...
# annual_salary                                                    1126000
# work_experience                                                      119
# years_to_retirement                                                  279
# dtype: object
# SynapseWidget(Synapse.DataFrame, 02a7b441-3b0b-4581-99d8-273426e0dbc2)
# name             GraceFrankEveDavidCharlieLeoNinaBobQuinnMiaRit...
# age                                                            566
# annual_salary                                              1126000
# dtype: object

# %% [markdown]
# ### Task 6: Data Aggregation
# Objective: Perform group-based aggregation.
#
# Instructions:
#
# Group the data by department and calculate the average salary for each department.

# %%
avg_salary_by_dept = df.groupby('department')['annual_salary'].mean().reset_index()

display(avg_salary_by_dept)
# Out:
# StatementMeta(, c3b0ff2f-23f5-4749-8c1b-28e8f6692ef3, 24, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 933bbf59-05ef-4684-8144-b472efcfe27e)

# %% [markdown]
# Good work. You forgot to display the first few rows. You can display it using .head() function. Similalrly, use describe function to show the summary of the dataframe. In task 4, first you need to introduce the null value and then replace those values with mean value. You forgot to introduce the null value. You can use numpy.nan function to introduce the null value.
